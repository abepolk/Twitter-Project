# %%
#Find a way to save the tweet to disk

import json
import oauth2 as oauth
import os
import emoji as emo
import urllib.parse as parse
import csv
from sklearn.feature_extraction.text import CountVectorizer
from stemming.porter2 import stem
from string import punctuation
import numpy
import pymongo
import re
import unicodedata
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

# %%
#This function will use an online ready-made dictionary to find the sentiment of an emoji

#load csv info into dictionary
emoji_scores = {}
with open('Emoji_Sentiment_Data_v1.0.csv', newline = '') as emoji_csv:
    emoji_reader = csv.reader(emoji_csv)
    next(emoji_reader, None)
    for row in emoji_reader:
        emoji = row[0]
        neg_score = float(int(row[4])/int(row[2]))
        neut_score = float(int(row[5])/int(row[2]))
        pos_score = float(int(row[6])/int(row[2]))
        sent_score = (-1 * neg_score + pos_score) - .305
        emoji_scores[emoji] = sent_score
        
#print(emoji_scores)

# %%
consumer_key = os.environ.get('CONSUMER_KEY')
consumer_secret = os.environ.get('CONSUMER_SECRET')

access_token = os.environ.get('ACCESS_TOKEN')
access_token_secret = os.environ.get('ACCESS_TOKEN_SECRET')

consumer = oauth.Consumer(key=consumer_key, secret=consumer_secret)
access_token = oauth.Token(key=access_token, secret=access_token_secret)
client = oauth.Client(consumer, access_token)



emo_tweets = {}
for i in range(0, 10):
    params = {'q' : 'Justin Bieber', 'count' : 100, 'lang' : 'en'}
    # See Twitter Search API documenation for description of cursoring for below if block
    if i > 0:
        params['max_id'] = max_id 
    timeline_endpoint_baseuri = 'https://api.twitter.com/1.1/search/tweets.json?'
    timeline_endpoint = timeline_endpoint_baseuri + parse.urlencode(params)
    print(timeline_endpoint)
    response, data = client.request(timeline_endpoint)
    tweets_results = json.loads(data)
    tweets_list = tweets_results['statuses']
    max_id = tweets_list[len(tweets_list) - 1]['id'] - 1
    for tweet in tweets_list:
        tweet_emojis = []
        for char in tweet['text']:
            if char in emo.UNICODE_EMOJI:
                tweet_emojis.append(char)
        if tweet_emojis:
            for emoji in tweet_emojis:
                tweet_emoji_scores = []
                try:
                    tweet_emoji_scores.append(emoji_scores[emoji])
                except KeyError as e:
                    print('No emoji %s' % e)
                    continue
            if tweet_emoji_scores:
                if max(tweet_emoji_scores) == max(numpy.absolute(tweet_emoji_scores)):
                    tweet_score = max(tweet_emoji_scores)
                else:
                    tweet_score = min(tweet_emoji_scores)
                emo_tweets[tweet['id']] = [tweet['text'], tweet_score]
    print('Emoji tweets processed: ' + str(len(emo_tweets.keys())))
            

for tweet in emo_tweets.values():
    print(tweet)
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5d8a71b47c64> in <module>()
#       5 access_token_secret = os.environ.get('ACCESS_TOKEN_SECRET')
#       6
# ----> 7 consumer = oauth.Consumer(key=consumer_key, secret=consumer_secret)
#       8 access_token = oauth.Token(key=access_token, secret=access_token_secret)
#       9 client = oauth.Client(consumer, access_token)
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/oauth2/__init__.py in __init__(self, key, secret)
#     207
#     208         if self.key is None or self.secret is None:
# --> 209             raise ValueError("Key and secret must be set.")
#     210
#     211     def __str__(self):
#
# ValueError: Key and secret must be set.

# %%
# text preprocessing (partially from before partially from August)
mongo_uri = 'mongodb://heroku_xgnhblcr:' + os.environ.get('MONGODB_PASSWORD') + '@ds149511.mlab.com:49511/heroku_xgnhblcr'
client = pymongo.MongoClient(mongo_uri)
db = client.get_default_database()
myresults = list(db.test.find())
tweets = []
emoji_tweets = []
for entry in myresults:
    tweets.append(entry['text'])
#Doing the next part based on the earlier REST-API-using cell
for tweet in tweets:
    tweet_emojis = []
    for char in tweet:
        if char in emo.UNICODE_EMOJI:
            tweet_emojis.append(char)
    if tweet_emojis:
        for emoji in tweet_emojis:
            tweet_emoji_scores = []
            try:
                tweet_emoji_scores.append(emoji_scores[emoji])
            except KeyError as e:
                print('No emoji score for %s' % e)
                continue
            if tweet_emoji_scores:
                if max(tweet_emoji_scores) == max(numpy.absolute(tweet_emoji_scores)):
                    tweet_score = max(tweet_emoji_scores)
                else:
                    tweet_score = min(tweet_emoji_scores)
                emoji_tweets.append([tweet, tweet_score])
    
print(emoji_tweets)
# Out:
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏽'
# No emoji score for '🤷'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤦'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🙂'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '‼'
# No emoji score for '🏾'
# No emoji score for '🤦'
# No emoji score for '🤦'
# No emoji score for '🤘'
# No emoji score for '🙂'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🤷'
# No emoji score for '🏿'
# No emoji score for '🏾'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🏾'
# No emoji score for '🤦'
# No emoji score for '🏾'
# No emoji score for '🤦'
# No emoji score for '🤞'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🤞'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤞'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🤣'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤞'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏽'
# No emoji score for '‼'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤞'
# No emoji score for '🏽'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🤷'
# No emoji score for '🏽'
# No emoji score for '🌡'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🙃'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🏾'
# No emoji score for '🙂'
# [['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.4410869565217392], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.4083808392715756], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.40762458471760804], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.42745614035087715], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.35409090909090907], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.4083808392715756], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.35421787709497204], ['#internationalcatday i have 200 pics of teddy and none of the crackhead with the moustache ❤️💖💛💙💗💖💚💜 https://t.co/35fYBHMuHU', 0.3510170394036209], ["RT @yourfashionkils: No none of you niggas got my attention no I don't won't you or Anybody I love this #Solo shii so leave me alone 🙆🏾🙆🏾🙆🏾😎", 0.20377192982456144], ["RT @yourfashionkils: No none of you niggas got my attention no I don't won't you or Anybody I love this #Solo shii so leave me alone 🙆🏾🙆🏾🙆🏾😎", 0.20377192982456144], ["RT @yourfashionkils: No none of you niggas got my attention no I don't won't you or Anybody I love this #Solo shii so leave me alone 🙆🏾🙆🏾🙆🏾😎", 0.20377192982456144], ["RT @yourfashionkils: No none of you niggas got my attention no I don't won't you or Anybody I love this #Solo shii so leave me alone 🙆🏾🙆🏾🙆🏾😎", 0.188368700265252], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['RT @hotcouple1234: Titty Tuesday pt1 enjoy my tits!!!!!! Some are older newer stuff by this weekend, none the less enjoy😈😈😈😈 https://t.co/V…', -0.03730769230769232], ['RT @hotcouple1234: Titty Tuesday pt1 enjoy my tits!!!!!! Some are older newer stuff by this weekend, none the less enjoy😈😈😈😈 https://t.co/V…', -0.03730769230769232], ['RT @hotcouple1234: Titty Tuesday pt1 enjoy my tits!!!!!! Some are older newer stuff by this weekend, none the less enjoy😈😈😈😈 https://t.co/V…', -0.03730769230769232], ['RT @hotcouple1234: Titty Tuesday pt1 enjoy my tits!!!!!! Some are older newer stuff by this weekend, none the less enjoy😈😈😈😈 https://t.co/V…', -0.03730769230769232], ['RT @naseemmusa: She slaying both waaayys 😍 https://t.co/VRMyHC1kpU', 0.37293678251297374], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['My 5 are pretty cool none of us ever switched up so i love yall✊🏽 https://t.co/bmQ9tNDQ4c', 0.12833333333333335], ["I don't really care for none of them tbh 🤷🏾\u200d♀️ https://t.co/CiIkLjNN4r", 0.02833333333333332], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['Go for it please😂😂😂 https://t.co/3DhOh7Cy0K', -0.08403159622486661], ['Go for it please😂😂😂 https://t.co/3DhOh7Cy0K', -0.08403159622486661], ['Go for it please😂😂😂 https://t.co/3DhOh7Cy0K', -0.08403159622486661], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ['RT @OfficialTLC: Scrubs 🙅🏾 https://t.co/23kI8jgZun', -0.5110606060606061], ["RT @TheWorldOfFunny: trying to explain to bae that you wasn't flirting with other girls, but she's having none of it. 🤦\u200d♂️👈 https://t.co/dt…", -0.10499999999999998], ["RT @TheWorldOfFunny: trying to explain to bae that you wasn't flirting with other girls, but she's having none of it. 🤦\u200d♂️👈 https://t.co/ ...

# %%
tweet_text= []
for tweet in emoji_tweets:
    tweet_text.append(tweet[0])
    
    
def preprocessor(tweet):
    
    #remove accents
    normalized = unicodedata.normalize('NFKD', tweet)
    if normalized != tweet:
        tweet = ''.join([c for c in normalized if not unicodedata.combining(c)])
        
    tweet = tweet.lower()
    
    #remove URLs
    tweet = re.sub(r'https?:\/\/.*?(\s|$)', '', tweet)
    tweet = re.sub(r'@\w*?(\s|$)', '', tweet)
    tweet = re.sub(r'#\w*?(\s|$)', '', tweet)
    
    #remove RT (retweet) - this doesn't seem to work since 'rt' is in the preprocessed data
    tweet = re.sub('^rt\s', '', tweet)
    
    #Note - the preprocessor already seems to be removing emojis - no need for extra code
    
    # Regularize apostrophes from different parts of unicode
    tweet = re.sub('|'.join(['‘', '’', 'ʻ', 'ʼ']))
    
    return tweet
# Out:
#   File "<ipython-input-4-ae3150993e33>", line 26
#     tweet = re.sub('|'.join([‘', '’', 'ʻ', 'ʼ']))
#                              ^
# SyntaxError: invalid character in identifier

# %%
def tokenizer(tweet): #Currently troubleshooting function
    
    tokens = []
    token_pattern = '(^|(?!\w).)((\w|\')+)\W'
    token_matches = re.finditer(token_pattern, tweet)
    for token_match in token_matches:
        tokens.append(token_match.group(2))
    return tokens

print(tokenizer("Hard pass...I'll give as much respect as y'all did Barack...none 😒 https://t.co/UJcr4mrZRA"))
# Out:
# ['Hard', "I'll", 'as', 'respect', "y'all", 'Barack', 'none', 'https', 't']

# %%
vectorizer = CountVectorizer(preprocessor=preprocessor, tokenizer=tokenizer) #Make binary?  Does this prevent it from picking up one word twice in a tweet?
fit_tr = vectorizer.fit_transform(tweet_text)
print(vectorizer.get_feature_names())
print(fit_tr)
#   for word in emoji_tweets.split(): #This and following line should be removed and use regex instead.  Follow Downloads/pak-paroubek.pdf for preprocessing ideas, as well as downloads that were downloaded at a similar time
#      if word[0:4] == 'http':
            
#CountVectorizer().build_tokenizer()(tweet_text) #stop_words param to 'english' once you have only Eng tweets, this was indented within for loop at the beginning of August
# Out:
# ['100', '2', '23', '4', '610', 'a', 'a1_selfmade', 'about', 'acting', 'activities', 'adorable', 'affected', 'again', "ain't", 'aint', 'alive', 'all', 'also', 'always', 'amp', 'and', 'any', 'anyway', 'are', 'as', 'aspectzavi_', 'ass', 'at', 'auf', 'awesome', 'aye', 'ayourb', 'b', 'baby', 'bae', 'barack', 'bc', 'be', 'because', 'been', 'before', 'being', 'best', 'better', 'biggest', 'birthday', 'bitch', 'bitches', 'blue', 'body', 'bootzie8', 'bout', 'boyfriends', 'bruh', 'bts', 'but', 'bxtch', 'called', 'camp', 'can', "can't", 'cant', 'cardiac', 'care', 'caroline', 'cause', 'challenge', 'cheering', 'chickadee', 'christyonnaaa', 'chxstainiac', 'clowning', 'cohen', 'colin', 'complaints', 'composure', 'concern', 'contestants', 'could', 'crazy', 'crypto', 'cuz', 'daisey_o', 'debsylee', 'deeroldrick', 'delete', 'dinesh_dezzy01', 'dleaf23', 'dm', 'do', "don't", 'done', 'driving', 'e', 'either', 'email', 'especially', 'ever', 'except', 'fact', 'facts', 'fan', 'favorite', 'felt', 'fiiiire', 'final', 'fluently', 'follow', 'footyscouted', 'for', 'friends', 'full', 'game', 'gassed', 'get', 'go', 'god', 'gone', 'gonna', 'good', 'gross', 'haleyygomez', 'half', 'hard', 'has', 'have', 'having', 'he', 'help', 'helps', 'her', 'highly', 'him', 'his', 'hmm', 'holbrookmaygen', 'honestly', 'hor', 'hoseokie', 'how', 'i', "i'll", "i'm", "i've", 'iamtxmtxm', 'if', 'im', 'in', 'information', 'innovations', 'into', 'involves', 'ion', 'is', "isn't", 'issaaabie', 'it', "it's", 'jociology', 'juicy', 'just', 'keep', 'kid', 'leandro', 'life', 'lifetime', 'lightning', 'like', 'lines', 'lmaoo', 'lmfaoo', 'lol', 'lonely', 'look', 'looking', 'lopsided', 'lot', 'lovebt3', 'm', 'madisonpettis', 'major', 'makes', 'makeup', 'making', 'manikind', 'many', 'mast', 'matter', 'me', 'messy', 'months', 'moxeebrushes', 'much', 'my', 'nail', 'need', 'never', 'new', 'niggas', 'night', 'no', 'none', 'not', 'nothing', 'odyssemil', 'of', 'off', 'offer', 'ohh', 'on', 'one', 'or', 'outside', 'over', 'pandaexpress', 'papaw', 'past', 'people', 'perfect', 'phrase', 'pics', 'point', 'practice', 'pressure', 'probation', 'queen_kaaayloni', 'queen_nyasia', 'rainy', 're', 'ready', 'really', 'red', 'rehearsal', 'relaxing', 'released', 'respect', 'rest', 'right', 'ross__vi', 's', 'say', 'sbspopasia', 'schnorr', 'second', 'see', 'she', 'shit', 'since', 'sleep', 'slight', 'sly', 'smellyahk202', 'so', 'social', 'softiedanny', 'soundcloud', 'spare', 'speak', 'spent', 'stealing', 'stop', 'supposedly', 't', 'tag', 'take', 'taking', 'tbh', 'tell', 'than', 'thank', 'thanks', 'that', 'thats', 'the', 'them', 'there', 'these', 'they', 'thing', 'think', 'this', 'those', 'thread', 'tickets', 'tied', 'till', 'time', 'to', 'tobdea', 'today', 'topics', 'trajanvii', 'turn', 'tyt', 'u', 'up', 'us', 'very', 'vickyleo6', 'wake', 'wannaone__data', 'want', 'watching', 'way', 'wear', 'were', 'what', 'when', 'who', 'whole', 'why', 'will', 'win', 'wiser', 'wishing', 'with', 'work', 'wrong', 'wtf', "y'all", 'ya', 'year', 'years', 'yhooooo', 'yoongi', 'you', "you're", 'your', 'yourself', 'আফস', 'আর', 'এ', 'কর', 'জ', 'ন', 'প', 'ফ', 'বনট', 'ম', 'র', 'স', '사이트안내', '워너원', '정보']
#   (0, 73)	1
#   (0, 221)	1
#   (0, 297)	1
#   (1, 125)	1
#   (1, 38)	1
#   (1, 42)	1
#   (1, 59)	1
#   (1, 20)	1
#   (1, 88)	1
#   (1, 325)	1
#   (2, 271)	1
#   (2, 201)	1
#   (2, 110)	1
#   (2, 152)	1
#   (2, 226)	1
#   (3, 140)	1
#   (3, 144)	1
#   (4, 140)	1
#   (4, 144)	1
#   (5, 140)	1
#   (5, 144)	1
#   (6, 138)	1
#   (6, 165)	1
#   (6, 33)	1
#   (6, 193)	1
#   :	:
#   (164, 262)	1
#   (164, 248)	1
#   (164, 140)	1
#   (165, 323)	1
#   (165, 280)	1
#   (165, 287)	1
#   (165, 140)	1
#   (166, 236)	1
#   (166, 9)	1
#   (166, 109)	1
#   (166, 252)	2
#   (166, 273)	1
#   (166, 193)	1
#   (166, 140)	1
#   (166, 201)	1
#   (166, 59)	1
#   (167, 167)	1
#   (167, 198)	1
#   (167, 205)	1
#   (167, 5)	1
#   (167, 140)	1
#   (168, 342)	1
#   (168, 341)	1
#   (168, 343)	1
#   (168, 300)	1

# %%
transformer = TfidfTransformer()  # This block is not correct
tfidf = transformer.fit_transform(fit_tr)

# %%
    tweet_emos = []
    for tweet in emoji_tweets:
        tweet_emos.append(tweet[1] > 0)
        
    
    #Cross-validation
    from sklearn.model_selection import cross_val_score
    print(type(tfidf.toarray()))
          
    scores = cross_val_score(MultinomialNB(alpha=.01), tfidf, tweet_emos, cv=5)
    print(scores)
# Out:
# <class 'numpy.ndarray'>
# [ 0.52941176  0.52941176  0.55882353  0.35294118  0.57575758]

# %%
    
    
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    MultinomialNB(alpha=.01).fit(X_train, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)
