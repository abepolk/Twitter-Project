# %%
#Find a way to save the tweet to disk

import json
import oauth2 as oauth
import os
import emoji as emo
import urllib.parse as parse
import csv
from sklearn.feature_extraction.text import CountVectorizer
from stemming.porter2 import stem
from string import punctuation
import numpy
import pymongo
import re
import unicodedata
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

# %%
#This function will use an online ready-made dictionary to find the sentiment of an emoji

#load csv info into dictionary
emoji_scores = {}
with open('Emoji_Sentiment_Data_v1.0.csv', newline = '') as emoji_csv:
    emoji_reader = csv.reader(emoji_csv)
    next(emoji_reader, None)
    for row in emoji_reader:
        emoji = row[0]
        neg_score = float(int(row[4])/int(row[2]))
        neut_score = float(int(row[5])/int(row[2]))
        pos_score = float(int(row[6])/int(row[2]))
        sent_score = (-1 * neg_score + pos_score) - .305
        emoji_scores[emoji] = sent_score
        
#print(emoji_scores)

# %%
consumer_key = os.environ.get('CONSUMER_KEY')
consumer_secret = os.environ.get('CONSUMER_SECRET')

access_token = os.environ.get('ACCESS_TOKEN')
access_token_secret = os.environ.get('ACCESS_TOKEN_SECRET')

consumer = oauth.Consumer(key=consumer_key, secret=consumer_secret)
access_token = oauth.Token(key=access_token, secret=access_token_secret)
client = oauth.Client(consumer, access_token)

# %%
# text preprocessing (partially from before partially from August)
mongo_uri = 'mongodb://heroku_xgnhblcr:' + os.environ.get('MONGODB_PASSWORD') + '@ds149511.mlab.com:49511/heroku_xgnhblcr'
client = pymongo.MongoClient(mongo_uri)
db = client.get_default_database()
myresults = list(db.Justin_Bieber.find())
tweets = []
emoji_tweets = []
for entry in myresults:
    tweets.append(entry['text'])
#Doing the next part based on the earlier REST-API-using cell
for tweet in tweets:
    tweet_emojis = []
    for char in tweet:
        if char in emo.UNICODE_EMOJI:
            tweet_emojis.append(char)
    if tweet_emojis:
        for emoji in tweet_emojis:
            tweet_emoji_scores = []
            try:
                tweet_emoji_scores.append(emoji_scores[emoji])
            except KeyError as e:
                continue
            if tweet_emoji_scores:
                if max(tweet_emoji_scores) == max(numpy.absolute(tweet_emoji_scores)):
                    tweet_score = max(tweet_emoji_scores)
                else:
                    tweet_score = min(tweet_emoji_scores)
                emoji_tweets.append([tweet, tweet_score])
    
print(emoji_tweets)
# Out:
# No emoji score for '🙃'
# No emoji score for '🏼'
# No emoji score for '🙄'
# No emoji score for '↗'
# No emoji score for '🤦'
# No emoji score for '🏼'
# No emoji score for '🤦'
# No emoji score for '🏼'
# No emoji score for '🤑'
# No emoji score for '🥀'
# No emoji score for '🤑'
# No emoji score for '🤳'
# No emoji score for '🏻'
# No emoji score for '↗'
# No emoji score for '🏻'
# No emoji score for '🙃'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🏻'
# No emoji score for '🤦'
# No emoji score for '🏻'
# No emoji score for '🏽'
# No emoji score for '🏽'
# No emoji score for '🎙'
# No emoji score for '🙃'
# No emoji score for '🥀'
# No emoji score for '🖤'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '™'
# No emoji score for '🏼'
# No emoji score for '🤔'
# No emoji score for '🤔'
# No emoji score for '🤔'
# No emoji score for '🤔'
# No emoji score for '🙃'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🏽'
# No emoji score for '🤙'
# No emoji score for '🏽'
# No emoji score for '🙂'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '🏻'
# No emoji score for '🤶'
# No emoji score for '🏻'
# No emoji score for '🎙'
# No emoji score for '🤙'
# No emoji score for '🙂'
# No emoji score for '🤔'
# No emoji score for '🙄'
# No emoji score for '🤔'
# No emoji score for '🙄'
# No emoji score for '🙄'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🏽'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🏼'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🤔'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🤔'
# No emoji score for '🤧'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤷'
# No emoji score for '🏽'
# No emoji score for '🥀'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🏻'
# No emoji score for '⌨'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤤'
# No emoji score for '🤔'
# No emoji score for '🤔'
# No emoji score for '🤔'
# No emoji score for '🏽'
# No emoji score for '🤔'
# No emoji score for '🙄'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🤤'
# No emoji score for '🏼'
# No emoji score for '🏻'
# No emoji score for '🏻'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🏼'
# No emoji score for '🏽'
# No emoji score for '🙄'
# No emoji score for '🏼'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🤤'
# No emoji score for '🖌'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🏿'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '🤤'
# No emoji score for '🤗'
# No emoji score for '🏼'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🙁'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🗣'
# No emoji score for '🖤'
# No emoji score for '🖤'
# No emoji score for '🙂'
# No emoji score for '🙂'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🤷'
# No emoji score for '🏽'
# No emoji score for '🏻'
# No emoji score for '🙄'
# No emoji score for '🤷'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🤦'
# No emoji score for '🏻'
# No emoji score for '🏼'
# No emoji score for '🤦'
# No emoji score for '🏾'
# No emoji score for '🏼'
# No emoji score for '🏻'
# No emoji score for '🏼'
# No emoji score for '🏼'
# No emoji score for '🖖'
# No emoji score for '🏽'
# No emoji score for '🏼'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '🤗'
# No emoji score for '🙄'
# No emoji score for '🤷'
# No emoji score for '🏻'
# No emoji score for '📸'
# No emoji score for '📸'
# No emoji score for '🤗'
# No emoji score for '🤗'
# No emoji score for '📊'
# No emoji score for '🖕'
# No emoji score for '🏼'
# No emoji score for '🤑'
# [['#NowPlaying Friends (with BloodPop®) by Justin Bieber ♫ https://t.co/FyVAit173e', -0.02032846715328468], ["RT @jaehyunbom: Mark: I just chose Justin Bieber's song today bcs I wanted to tell a lot of people what of a fan I'm for him \n\nMark... 😂", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ['Friends by Justin Bieber &amp; BloodPop® is number 3 in Denmark #iTunes top 100 songs https://t.co/N2kNumqROr', -0.02032846715328468], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ['WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', -0.08403159622486661], ['WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', -0.08403159622486661], ['WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', -0.08403159622486661], ['❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', 0.4410869565217392], ['❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', 0.4410869565217392], ['❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', 0.4410869565217392], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0.08403159622486661], ['Mark Lee and his love for Justin B ❤ https://t.co/BPqqNEEdVf', 0.4410869565217392], ["RT @jaehyunbom: Mark: I usually listen to Justin Bieber bcs I'm his fan\nJN: You're a Believer?\nNCT: 😂😂😂😂😂\nMark: Okay you could put… ", -0. ...

# %%
# Remove retweets (starting with "RT")
emoji_tweets = [tweet for tweet in emoji_tweets if not tweet[0].startswith('RT')]

tweet_text = [tweet[0] for tweet in emoji_tweets]

# %%
print(tweet_text[0:100])
# Out:
# ['#NowPlaying Friends (with BloodPop®) by Justin Bieber ♫ https://t.co/FyVAit173e', 'Friends by Justin Bieber &amp; BloodPop® is number 3 in Denmark #iTunes top 100 songs https://t.co/N2kNumqROr', 'WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', 'WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', 'WTG IS GOING ON\nJUSTIN BIEBER FOLLOWED A LOTS OF DOLAN TWIN STANS\nWHAT HAPPENED😂😂😂 \nIM SO HAPPY FOR THEM THO', '❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', '❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', '❤❤❤#Bieber #BestSeller New 2017 Justin Bieber Purpose The World Tour Hoodies Sweatshirts Yellow #JustinBieber #Deal… https://t.co/aM3UEijzA9', 'Mark Lee and his love for Justin B ❤ https://t.co/BPqqNEEdVf', '❤❤💚#Bieber #Clothing Justin Bieber Small 2013 Believe North American Concert Tour Graphic T-Shirt #JustinBieber…… https://t.co/kvbjiQdQrR', '❤❤💚#Bieber #Clothing Justin Bieber Small 2013 Believe North American Concert Tour Graphic T-Shirt #JustinBieber…… https://t.co/kvbjiQdQrR', '❤❤💚#Bieber #Clothing Justin Bieber Small 2013 Believe North American Concert Tour Graphic T-Shirt #JustinBieber…… https://t.co/kvbjiQdQrR', "@kumijennie Who is jefffffffrey i'm justin bieber ☺", '@Beats1 @zaynmalik I better see Drake or Justin Bieber on this album 😤', 'Friends - Justin Bieber &amp; Bloodpop® #NowPlaying #IstaraFM [20:01 wib]', '❤❤💚#JustinBieber #Buzz Lot of Justin Bieber book and magazine article collection #Bieber #Deals…… https://t.co/p9VLJZyOip', '❤❤💚#JustinBieber #Buzz Lot of Justin Bieber book and magazine article collection #Bieber #Deals…… https://t.co/p9VLJZyOip', '❤❤💚#JustinBieber #Buzz Lot of Justin Bieber book and magazine article collection #Bieber #Deals…… https://t.co/p9VLJZyOip', 'this is awesome 😄 ☺️ https://t.co/qutH7P6uUW', 'this is awesome 😄 ☺️ https://t.co/qutH7P6uUW', 'sounds great.. 🙌 https://t.co/HqhiKKSa7c', 'dude 😊 😝 https://t.co/07nq2ahShX', 'dude 😊 😝 https://t.co/07nq2ahShX', 'yes absolutely! nothing like us by justin bieber 💯 https://t.co/29KY2cm3PR', '@oharps_ Lol justin bieber and jason derulo are on the beach we go to 😂', 'dude 😛 💓 https://t.co/Lxf980XK0V', 'dude 😛 💓 https://t.co/Lxf980XK0V', 'thats true! 🙈 🙈 https://t.co/mUIt6G0wtd', 'thats true! 🙈 🙈 https://t.co/mUIt6G0wtd', 'thats true 👅 😄 https://t.co/TMwfVskSMz', 'thats true 👅 😄 https://t.co/TMwfVskSMz', 'yeahh… 💜 ❤️ https://t.co/5yrPBRHoOP', 'yeahh… 💜 ❤️ https://t.co/5yrPBRHoOP', '♫ #NowPlaying “Friends” by BloodPop® &amp; Justin Bieber on #Anghami https://t.co/9NO2tfJSF0', 'you know… 😜 👍 https://t.co/U16MSACdX9', 'you know… 😜 👍 https://t.co/U16MSACdX9', 'yeahh 🙀 👿 https://t.co/3TRlK3jfJ1', 'yeahh 🙀 👿 https://t.co/3TRlK3jfJ1', 'never.. 😍 😎 https://t.co/DW8zeiaQPf', 'never.. 😍 😎 https://t.co/DW8zeiaQPf', '❤💚#Jewelry #Watches aLTeReD JUSTIN BIEBER Fans Designer Styled Bracelet #JustinBieber #Style… https://t.co/ol25MP2OJ2', '❤💚#Jewelry #Watches aLTeReD JUSTIN BIEBER Fans Designer Styled Bracelet #JustinBieber #Style… https://t.co/ol25MP2OJ2', "Hi I'm new I'm from Poland I'm a big fan of Justin Bieber! And Angeliki Mucha😍😍", "Hi I'm new I'm from Poland I'm a big fan of Justin Bieber! And Angeliki Mucha😍😍", 'Friends by Justin Bieber is actually really good⚡', 'Friends / Justin Bieber &amp; BloodPop®\nby かじ\n#nanamusic\n https://t.co/z24s1I9IIh https://t.co/zljnWYdqRq', 'Purpose by Justin Bieber 💕 https://t.co/cpPmNTw4ao', "I'm 😂💀 never heard of this one https://t.co/2tGCpoEyOt", "I'm 😂💀 never heard of this one https://t.co/2tGCpoEyOt", 'Bye all my money 👋🏼 https://t.co/bbT8XvW9G8', '@mixoneddlovato 🍒💗🌸💦⚡ 一 mark my words, Justin Bieber.', '@mixoneddlovato 🍒💗🌸💦⚡ 一 mark my words, Justin Bieber.', '@mixoneddlovato 🍒💗🌸💦⚡ 一 mark my words, ...

# %%
    
def preprocessor(tweet):
    
    if tweet.startswith('RT'):
        return ''
    #remove accents
    normalized = unicodedata.normalize('NFKD', tweet)
    if normalized != tweet:
        tweet = ''.join([c for c in normalized if not unicodedata.combining(c)])
        
    tweet = tweet.lower()
    
    #remove URLs
    tweet = re.sub(r'https?:\/\/.*?(\s|$)', '', tweet)
    tweet = re.sub(r'@\w*?(\s|$)', '', tweet)
    tweet = re.sub(r'#\w*?(\s|$)', '', tweet)
    
    #remove RT (retweet) - this doesn't seem to work since 'rt' is in the preprocessed data
    # This is unnecessary if I remove them in the beginning of the preprocessor
    tweet = re.sub('^rt\s', '', tweet)
    
    #Note - the preprocessor already seems to be removing emojis - no need for extra code
    
    # Regularize apostrophes from different parts of unicode
    tweet = re.sub('|'.join(['‘', '’', 'ʻ', 'ʼ']), '\'', tweet)
    
    return tweet

# %%
def tokenizer(tweet): #Currently troubleshooting function
    
    tokens = []
    token_pattern = '(^|(?!\w).)((\w|\')+)\W'
    token_matches = re.finditer(token_pattern, tweet)
    for token_match in token_matches:
        tokens.append(token_match.group(2))
    return tokens

print(tokenizer("Hard pass...I'll give as much respect as y'all did Barack...none 😒 https://t.co/UJcr4mrZRA"))
# Out:
# ['Hard', "I'll", 'as', 'respect', "y'all", 'Barack', 'none', 'https', 't']

# %%
vectorizer = CountVectorizer(preprocessor=preprocessor, tokenizer=tokenizer) #Make binary?  Does this prevent it from picking up one word twice in a tweet?
fit_tr = vectorizer.fit_transform(tweet_text)
print(vectorizer.get_feature_names())
#   for word in emoji_tweets.split(): #This and following line should be removed and use regex instead.  Follow Downloads/pak-paroubek.pdf for preprocessing ideas, as well as downloads that were downloaded at a similar time
#      if word[0:4] == 'http':
            
#CountVectorizer().build_tokenizer()(tweet_text) #stop_words param to 'english' once you have only Eng tweets, this was indented within for loop at the beginning of August
# Out:
# ["'", "'i'm", "'n", "'s", '04', '05', '06', '1', '10', '100', '100m', '11', '12', '13x19', '15', '17', '18', '2', '20', '2010', '2012', '2016', '21', '22', '2e', '2u', '3', '40', '6th', '7', '75', '8', '8x10', 'a', 'aaaa', 'aaaaaaah', 'aaaaaall', 'abbott', 'about', 'according', 'accutime', 'achieve', 'acoustic', 'acts', 'actually', 'added', 'adesso', 'again', 'ah', 'aire', 'aka', 'alarm', 'album', 'all', 'almond', 'alone', 'altered', 'always', 'am', 'american', 'amo', 'amp', 'an', 'and', 'angel', 'animated', 'anime', 'anita', 'another', 'answer', 'antivist', 'any', 'anymore', 'anything', 'app', 'apple', 'are', 'ariana', 'artist', 'as', 'ascoltala', 'asf', 'asked', 'asks', 'at', 'authentic', 'autographed', 'available', 'award', 'away', 'awesome', 'awnnn', 'baby', 'babyy', 'back', 'background', 'bangers', 'bank', 'barack', 'barely', 'barney', 'bbad', 'bbc', 'bc', 'bday', 'be', 'beat', 'beating', 'beautiful', 'because', 'bed', 'been', 'before', 'behave', 'being', 'belieber', 'beliebers', 'believe', 'believers', 'bernard', 'best', 'better', 'biebe', 'bieber', "bieber's", 'big', 'billboard', 'birthday', 'biξbξr', 'black', 'blanket', 'bloodpop', 'bloody', 'bomber', 'book', 'boots', 'both', 'bought', 'box', 'boyfriend', 'bracelet', 'break', 'breathe', 'bring', 'bro', 'broke', 'brotha', 'bruno', 'btw', 'bus', 'but', 'butt', 'buying', 'by', 'bye', 'calendar', 'california', 'callin', 'can', "can't", 'canadian', 'canceling', 'canttt', 'car', 'carino', 'carly', 'carter', 'cassper', 'caught', 'centerfold', 'chance', 'charming', 'check', 'checked', 'chillout', 'choking', 'choose', 'choreography', 'chris', 'christmas', 'church', 'cieee', 'cigarette', 'cindy', 'classic', 'clean', 'clock', 'clothes', 'co', 'coa', 'cody', 'cold', 'colder', 'collectible', 'collection', 'come', 'coming', 'comment', 'company', 'con', 'concert', 'conclusion', 'congrats', 'continue', "coordinator's", 'could', 'country', 'cover', 'credit', 'current', 'cute', 'da', 'dabbing', 'daddy', 'dagens', 'dale', 'damien', 'damn', 'david', 'davidguetta', 'day', 'days', 'de', 'deal', 'deals', 'defines', 'denmark', 'deserve', 'designer', 'despacito', 'destin', 'details', 'did', "didn't", 'didnt', 'din', 'dis', 'discover', 'display', 'disrespect', 'dj', 'dm', 'dms', 'do', 'doin', 'doing', 'dolan', "don't", 'donova', 'dont', 'down', 'drake', 'drew', 'drinks', 'dude', 'due', 'duh', 'during', 'e', 'each', 'early', 'earth', 'easton', 'easy', 'eazy', 'edt', 'else', 'em', 'en', 'enjoy', 'enter', 'entre', 'escucha', 'even', 'everyone', 'everything', 'excuse', 'experience', 'fabric', 'fags', 'fall', 'fame', 'fan', 'fanart', 'fanpage', 'fast', 'father', 'fav', 'favorite', 'favourite', 'fds', 'feat', 'feel', 'feels', 'fellas', 'felt', 'finally', 'finallyyyy', 'first', 'firstly', 'flatline', 'fm', 'fm1fm', 'fob', 'follow', 'followed', 'following', 'fonsi', 'football', 'for', 'forever', 'forgot', 'free', 'french', 'friends', "friends'", 'friendssss', 'fries', 'from', 'front', 'ft', 'fuck', 'fuckkkk', 'full', 'funk', 'funko', 'furious', 'future', 'gabriella', 'gaia', 'gave', 'german', 'get', 'getting', 'give', 'glow', 'go', 'goal', 'goes', 'going', 'good', 'google', 'gosh', 'gostar', 'got', 'great', 'gregory', 'guetta', 'guilty', 'guy', 'guys', 'h', 'hace', 'had', 'hahaha', 'hahha', 'hair', 'haircut', 'half', 'hanes', 'hangs', 'happened', 'happens', 'happy', 'hard', 'hardcove', 'harrison', 'harry', 'has', 'hat', 'have', 'hayes', 'he', "he's", 'hear', 'heart', 'heaven', 'hello', 'hemmings', 'her', 'here', 'hey', 'heyyy', 'hi', 'him', 'hips', 'his', 'hold', 'hollywood', 'holy', 'home', 'honestly', 'hoodies', 'hop', 'how', 'hugh', 'hype', 'i', "i'll", "i'm", 'if', 'im', 'imagine', 'in', 'incredible', 'infarta', 'inside', 'instagram', 'intellectuals', 'intentionally', 'is', "isn't", 'israel', 'it', "it's", 'its', 'j', 'jason', 'jazzy', 'jb', 'jbxreader', 'jefffffffrey', 'jepsen', 'jesus', "jhope's", 'joe', 'joins', 'jojo', 'joox', 'jumpers', 'jungkook', 'just', 'justin', 'justinbieber', 'karla', 'k ...

# %%
transformer = TfidfTransformer()  # This block is not correct
tfidf = transformer.fit_transform(fit_tr)

# %%
    tweet_emos = []
    for tweet in emoji_tweets:
        tweet_emos.append(tweet[1] > 0)
        
    
    #Cross-validation
    from sklearn.model_selection import cross_val_score
    print(type(tfidf.toarray()))
          
    scores = cross_val_score(MultinomialNB(alpha=.01), tfidf, tweet_emos, cv=5) #this takes forever at cv=10
    print(scores)
# Out:
# <class 'numpy.ndarray'>
# [ 0.71428571  0.72426471  0.61397059  0.70220588  0.8125    ]

# %%
    
    
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    MultinomialNB(alpha=.01).fit(X_train, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)
# Out:
# ________________________________________________________________________________
# Training:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-cea2c00434b9> in <module>()
#       3 print('_' * 80)
#       4 print("Training: ")
# ----> 5 print(clf)
#       6 t0 = time()
#       7 MultinomialNB(alpha=.01).fit(X_train, y_train)
#
# NameError: name 'clf' is not defined
